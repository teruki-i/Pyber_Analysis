# %% [markdown]
# # Pyber Challenge

# %% [markdown]
# ### 4.3 Loading and Reading CSV files

# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Add Matplotlib notebook magic command
# %matplotlib notebook
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# File to Load (Remember to change these)
city_data_to_load = "Resources/city_data.csv"
ride_data_to_load = "Resources/ride_data.csv"

# Read the City and Ride Data
city_data_df = pd.read_csv(city_data_to_load)
ride_data_df = pd.read_csv(ride_data_to_load)

# %% [markdown]
# ### Merge the DataFrames

# %%
# Combine the data into a single dataset
pyber_data_df = pd.merge(ride_data_df, city_data_df, how="left", on=["city", "city"])

# Display the data table for preview
pyber_data_df.head()
# Out:
#                  city                 date   fare        ride_id  \
# 0  Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1  South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2  Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3          Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4          South Jack  2019-03-06 04:28:35  34.58  3908451377344
#
#    driver_count   type
# 0             5  Urban
# 1            72  Urban
# 2            57  Urban
# 3            34  Urban
# 4            46  Urban

# %% [markdown]
# ## Deliverable 1: Get a Summary DataFrame

# %%
#  1. Get the total rides for each city type
ride_count_by_type = pyber_data_df.groupby(pyber_data_df['type'])['ride_id'].count()

# %%
# 2. Get the total drivers for each city type
drivers_by_type = city_data_df.groupby(city_data_df['type']).sum()['driver_count']
drivers_by_type
# Out:
# type
# Rural         78
# Suburban     490
# Urban       2405
# Name: driver_count, dtype: int64

# %%
#  3. Get the total amount of fares for each city type
fares_by_type = pyber_data_df.groupby(pyber_data_df['type'])['fare'].sum()
fares_by_type
# Out:
# type
# Rural        4327.93
# Suburban    19356.33
# Urban       39854.38
# Name: fare, dtype: float64

# %%
#  4. Get the average fare per ride for each city type.
avg_ride_fare_by_type = fares_by_type / ride_count_by_type
avg_ride_fare_by_type
# Out:
# type
# Rural       34.623440
# Suburban    30.970128
# Urban       24.525772
# dtype: float64

# %%
# 5. Get the average fare per driver for each city type. 
avg_driver_fare_by_type = fares_by_type / drivers_by_type
avg_driver_fare_by_type
# Out:
# type
# Rural       55.486282
# Suburban    39.502714
# Urban       16.571468
# dtype: float64

# %%
#  6. Create a PyBer summary DataFrame. 
pyber_summary_df = pd.DataFrame({"Total Number of Rides":ride_count_by_type,
                    "Total Number of Drivers":drivers_by_type,
                    "Total Fares":fares_by_type,
                    "Average Fare per Ride":avg_ride_fare_by_type,
                    "Average Fare per Driver":avg_driver_fare_by_type
                    })

pyber_summary_df
# Out:
#           Total Number of Rides  Total Number of Drivers  Total Fares  \
# type
# Rural                       125                       78      4327.93
# Suburban                    625                      490     19356.33
# Urban                      1625                     2405     39854.38
#
#           Average Fare per Ride  Average Fare per Driver
# type
# Rural                 34.623440                55.486282
# Suburban              30.970128                39.502714
# Urban                 24.525772                16.571468

# %%
#  7. Cleaning up the DataFrame. Delete the index name
pyber_summary_df.index.name = None
pyber_summary_df
# Out:
#           Total Number of Rides  Total Number of Drivers  Total Fares  \
# Rural                       125                       78      4327.93
# Suburban                    625                      490     19356.33
# Urban                      1625                     2405     39854.38
#
#           Average Fare per Ride  Average Fare per Driver
# Rural                 34.623440                55.486282
# Suburban              30.970128                39.502714
# Urban                 24.525772                16.571468

# %%
#  8. Format the columns.
pyber_summary_df["Total Number of Rides"] = pyber_summary_df["Total Number of Rides"].map("{:,.0f}".format)
pyber_summary_df["Total Number of Drivers"] = pyber_summary_df["Total Number of Drivers"].map("{:,.0f}".format)
pyber_summary_df["Total Fares"] = pyber_summary_df["Total Fares"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Ride"] = pyber_summary_df["Average Fare per Ride"].map("${:,.2f}".format)
pyber_summary_df["Average Fare per Driver"] = pyber_summary_df["Average Fare per Driver"].map("${:,.2f}".format)

pyber_summary_df
# Out:
#          Total Number of Rides Total Number of Drivers Total Fares  \
# Rural                      125                      78   $4,327.93
# Suburban                   625                     490  $19,356.33
# Urban                    1,625                   2,405  $39,854.38
#
#          Average Fare per Ride Average Fare per Driver
# Rural                   $34.62                  $55.49
# Suburban                $30.97                  $39.50
# Urban                   $24.53                  $16.57

# %% [markdown]
# ## Deliverable 2.  Create a multiple line plot that shows the total weekly of the fares for each type of city.

# %%
# 1. Read the merged DataFrame
pyber_data_df
# Out:
#                     city                 date   fare        ride_id  \
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
#       driver_count   type
# 0                5  Urban
# 1               72  Urban
# 2               57  Urban
# 3               34  Urban
# ...

# %%
# 2. Using groupby() to create a new DataFrame showing the sum of the fares 
#  for each date where the indices are the city type and date.
sum_fare_by_citytype_date = pyber_data_df.groupby(["type","date"]).sum()["fare"]

# %%
# 3. Reset the index on the DataFrame you created in #1. This is needed to use the 'pivot()' function.
# df = df.reset_index()
fare_by_citytype_date_df = sum_fare_by_citytype_date.reset_index()

# %%
# check DataFrame

fare_by_citytype_date_df.head()
# Out:
#     type                 date   fare
# 0  Rural  2019-01-01 09:45:36  43.69
# 1  Rural  2019-01-02 11:18:32  52.12
# 2  Rural  2019-01-03 19:51:01  19.90
# 3  Rural  2019-01-04 03:31:26  24.88
# 4  Rural  2019-01-06 07:38:40  47.33

# %%
# 4. Create a pivot table with the 'date' as the index, the columns ='type', and values='fare' 
# to get the total fares for each type of city by the date. 



# create pivot table
fare_by_citydate_piv = pd.pivot_table(fare_by_citytype_date_df,
                                      values = 'fare',
                                      index = ['date'],
                                     columns = ['type'])

fare_by_citydate_piv
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-05-08 04:20:00    NaN       NaN  21.99
# 2019-05-08 04:39:49    NaN       NaN  18.45
# 2019-05-08 07:29:01    NaN       NaN  18.55
# 2019-05-08 11:38:35    NaN       NaN  19.77
# 2019-05-08 13:10:18    NaN       NaN  18.04
#
# [2375 rows x 3 columns]

# %%
# 5. Create a new DataFrame from the pivot table DataFrame using loc on the given dates, '2019-01-01':'2019-04-29'.
fares_Jan_Apr_df = fare_by_citydate_piv.loc['2019-01-01':'2019-04-29']
fares_Jan_Apr_df
# Out:
# type                 Rural  Suburban  Urban
# date
# 2019-01-01 00:08:16    NaN       NaN  37.91
# 2019-01-01 00:46:46    NaN     47.74    NaN
# 2019-01-01 02:07:24    NaN     24.07    NaN
# 2019-01-01 03:46:50    NaN       NaN   7.57
# 2019-01-01 05:23:21    NaN       NaN  10.75
# ...                    ...       ...    ...
# 2019-04-28 14:28:36    NaN       NaN  11.46
# 2019-04-28 16:29:16    NaN       NaN  36.42
# 2019-04-28 17:26:52    NaN       NaN  31.43
# 2019-04-28 17:38:09    NaN     34.87    NaN
# 2019-04-28 19:35:03    NaN     16.96    NaN
#
# [2196 rows x 3 columns]

# %%
# 6. Set the "date" index to datetime datatype. This is necessary to use the resample() method in Step 8.
# df.index = pd.to_datetime(df.index)

fares_Jan_Apr_df.index = pd.to_datetime(fares_Jan_Apr_df.index)

# %%
# 7. Check that the datatype for the index is datetime using df.info()
fares_Jan_Apr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2196 entries, 2019-01-01 00:08:16 to 2019-04-28 19:35:03
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Rural     114 non-null    float64
#  1   Suburban  573 non-null    float64
#  2   Urban     1509 non-null   float64
# dtypes: float64(3)
# memory usage: 68.6 KB

# %%
# 8. Create a new DataFrame using the "resample()" function by week 'W' and get the sum of the fares for each week.
weekly_fares_Jan_Apr_df = fares_Jan_Apr_df.resample('W').sum()
weekly_fares_Jan_Apr_df.head()
# Out:
# type         Rural  Suburban    Urban
# date
# 2019-01-06  187.92    721.60  1661.68
# 2019-01-13   67.65   1105.13  2050.43
# 2019-01-20  306.00   1218.20  1939.02
# 2019-01-27  179.69   1203.28  2129.51
# 2019-02-03  333.08   1042.79  2086.94

# %%
# 8. Using the object-oriented interface method, plot the resample DataFrame using the df.plot() function. 
#weekly_fares = weekly_fares_Jan_Apr_df.plot(kind='line')
fig = plt.figure(figsize = (20,6))
ax = fig.add_subplot()
weekly_fares_Jan_Apr_df.plot(ax=ax)

# Import the style from Matplotlib.
from matplotlib import style

# Use the graph style fivethirtyeight.
style.use('fivethirtyeight')

# Add Labels
ax.set_title('Total Fare by City Type')
ax.set_ylabel('Total Fare ($USD)')
ax.set_xlabel('')

# Set legend location
ax.legend(loc = 'upper left', borderpad=0)

plt.show()

plt.savefig('analysis/Pyber_fare_summary.png')
# Out:
# <img src="data:image/png;base64,..." width="1440">
